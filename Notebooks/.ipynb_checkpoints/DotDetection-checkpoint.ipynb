# %% [markdown]
# ##  Dot Detection
# This notebook allows the dot detection on smFISH data processing all folders

# %% [markdown]
# ## Imports and setup

# %%
import os
import sys
from pathlib import Path

# Add the NuclearSegmentation folder to Python path
project_root = Path.cwd().parent  # Assuming notebook is in Notebooks folder
module_path = project_root / "DotDetection"
sys.path.insert(0, str(module_path))

# Import
from Dot_detection_functions import process_fish_spots

# %%
input_root = r"C:\Users\josed\gitHub\Wormfish\data" # Change to your desired input folder

# %% [markdown]
# ## Dot detection on all positions within a root folder
# Function iterates over all pos# folders and outsputs a numpy files for the dots detected in two channels.
# Change parameters as needed.
# Results are saved in a DotDetection folder within the root directory.

# %%
process_fish_spots(
    input_root=input_root,
    output_root=None,
    voxel_size=(1000, 103, 103), 
    spot_radius=(1050, 300, 300),
    a647_threshold=15,
    a647_alpha=0.5,
    a647_beta=1.7,
    a647_gamma=15,
    cy3b_threshold=25,
    cy3b_alpha=0.5,
    cy3b_beta=1.7,
    cy3b_gamma=25
)
# Out:
# ...
# FISH Spot Detection Pipeline
# ...
# Voxel size: (1000, 103, 103)
# Spot radius: (1050, 300, 300)
# A647 Parameters: threshold=15, alpha=0.5, beta=1.7, gamma=15
# CY3B Parameters: threshold=25, alpha=0.5, beta=1.7, gamma=25
#
# Input: C:\Users\josed\gitHub\Wormfish\data
# Output: C:\Users\josed\gitHub\Wormfish\data\DetectedDots
#
# Found 2 pos folders
#
# Processing pos0: 2 .tif files
#
# [1/2] Processing: hyb_0_pos0.tif
#   Processing A647 channel...
#     A647 - before decomposition: (1, 3)
#     A647 - after decomposition: (1, 3)
#   Processing CY3B channel...
#     CY3B - before decomposition: (1, 3)
#     CY3B - after decomposition: (1, 3)
#   ✓ Saved spots for: hyb_0_pos0
#
# [2/2] Processing: hyb_1_pos0.tif
#   Processing A647 channel...
#     A647 - before decomposition: (5, 3)
#     A647 - after decomposition: (5, 3)
#   Processing CY3B channel...
#     CY3B - before decomposition: (2, 3)
#     CY3B - after decomposition: (2, 3)
#   ✓ Saved spots for: hyb_1_pos0
#
# ...
