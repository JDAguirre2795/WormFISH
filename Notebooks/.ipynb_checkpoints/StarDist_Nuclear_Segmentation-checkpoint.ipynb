# %%
import os
import sys
from pathlib import Path

# Add the NuclearSegmentation folder to Python path
project_root = Path.cwd().parent  # Assuming notebook is in Notebooks folder
module_path = project_root / "NuclearSegmentation"
sys.path.insert(0, str(module_path))

# Import the processor
from nuclear_segmentation import (
    process_all_images, 
    check_folder_structure,
    process_directory_DAPI_hyb0,
    process_directory_all_hyb
)
# Out:
# __init__.py (86): Unable to find acceptable character detection dependency (chardet or charset_normalizer).

# %%
input_root = r"C:\Users\josed\gitHub\Wormfish\data"
model_path = r'C:\Users\josed\models'  # Your model directory
model_name = 'stardistV2.6'

print(f"Input directory: {input_root}")
print(f"Model path: {model_path}")
print(f"Model name: {model_name}")
# Out:
# Input directory: C:\Users\josed\gitHub\Wormfish\data
# Model path: C:\Users\josed\models
# Model name: stardistV2.6

# %%
process_all_images(
    input_root=input_root,
    output_root=None,  # Will create NuclearMasks folder automatically
    model_path=model_path,
    model_name=model_name,
    process_all_hyb=True  #True process all hybs, False process hyb0 only
)
# Out:
# ...
# StarDist 3D Nuclear Segmentation
# ...
# Output directory not specified, using: C:\Users\josed\gitHub\Wormfish\data\NuclearMasks
# Saving masks to: C:\Users\josed\gitHub\Wormfish\data\NuclearMasks
#
# Loading model stardistV2.6...
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.436838, nms_thresh=0.3.
#
# Processing images from: C:\Users\josed\gitHub\Wormfish\data
# Mode: Processing ALL hyb_* files
#
# Searching for ALL hyb files in: C:\Users\josed\gitHub\Wormfish\data
# Found 2 pos folders: ['pos0', 'pos1']
#
# pos0: Found 2 hyb files
#   [1/2] Processing: hyb_0_pos0.tif
#   DAPI shape: (10, 3, 80)
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.15it/s]
#   ✓ Saved to: pos0/Masks_hyb_0_pos0.npy
#   [2/2] Processing: hyb_1_pos0.tif
#   DAPI shape: (10, 3, 80)
# ...
