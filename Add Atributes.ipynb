# %%
import os
import h5py
import numpy as np

# %%
fn = r"F:\data\malemarkers\processed\20240213\CompiledH5\compiledpos1.h5"
h5 = h5py.File(fn, "a")

# Adding attributes
h5.attrs["N_points"] = 200
h5.attrs["T"] = 21
h5.attrs["C"] = 3
h5.attrs["W"] = 2048
h5.attrs["H"] = 2048
h5.attrs["D"] = 66
h5.attrs["description"] = "example data"

h5.close()

# %%
# Open the file
file = r"E:\data\CED3\20250405_FULLWORM_CED3POOL1_resaved\HybCycle_0\Worm1\fused\fused.h5"
with h5py.File(file, 'r') as f:
    # List all groups and datasets
    def printname(name):
        print(name)
    f.visit(printname)
# Out:
# __DATA_TYPES__
# __DATA_TYPES__/Enum_Boolean
# __DATA_TYPES__/String_VariableLength
# s00
# s00/resolutions
# s00/subdivisions
# t00000
# t00000/s00
# t00000/s00/0
# t00000/s00/0/cells
# t00000/s00/1
# t00000/s00/1/cells
# t00000/s00/2
# t00000/s00/2/cells
# t00000/s00/3
# t00000/s00/3/cells
# t00000/s00/4
# t00000/s00/4/cells
# t00000/s00/5
# t00000/s00/5/cells
# t00000/s00/6
# t00000/s00/6/cells
